# %%
# Load the json data from ../data/data.json and see how many entries there are
import json

with open("../data/data.json") as f:
    data = json.load(f)
    print(len(data))
# Out:
# 2565

# %%
data["11"]
# Out:
# {'organization': '0xCarbon',
#  'theme_id': 2,
#  'kyc_completed': True,
#  'display_id': 2,
#  'challenge_id': 1,
#  'country': 'Nigeria',
#  'sub_category_id': 452,
#  'categorizer_completed': True,
#  'category_id': 15,
#  'evaluator_completed': True,
#  'attachment_extractor_completed': False,
#  'assigned_reviewer': None,
#  'extractor_completed': False,
#  'user_status': 'Yes',
#  'user_comments': 'hello world',
#  'created_at': '2024-08-02T05:18:28.549019Z',
#  'id': 11,
#  'LLM_summary': '0xcarbon is a SaaS product that helps FMCG businesses in Southeast Asia reduce their carbon footprint. It uses big data, machine learning, and blockchain technology to provide businesses with suggestions for small incremental changes to their operations, connect them to green energy sources, and process carbon credits to offset unavoidable emissions. By providing accessible and effective tools for businesses to combat climate change, 0xcarbon aims to play a critical role in catalyzing the transition to a low-carbon economy.',
#  'updated_at': '2024-08-02T05:18:28.549019Z',
#  'title': '0xcarbon - Enabling a low carbon economy',
#  'LLM_status': 'No',
#  'jotform_id': '5842417944325746832',
#  'pre_aug_sixth': False,
#  'Challenge': 'Liveability Challenge 2024',
#  'Theme': 'Climate Change',
#  'Category': 'Carbon Management',
#  'Subcategory': 'Carbon Emissions Reduction through SaaS',
#  'form_fields': {'Project objectives': "Our primary objective at 0xcarbon is to help FMCGs in Africa reduce their carbon footprint and transition to a low-carbon economy. The company's goal is to leverage big data, machine learning, and blockchain technology to provide actionable insights and solutions to these businesses, enabling them to make incremental changes to their operations that reduce their carbon emissions. By doing so, 0xcarbon aims to offset an estimated 10,000,000 tons of CO2e/yr and contribute to the global effort to combat climate change. Additionally, the company aims to create a sustainable business model that generates revenue while driving positive environmental impact, demonstrating the viability of market-based solutions for addressing sustainability challenges.",
#   'Project stage (https://www.nasa.gov/pdf/458490main_TRL_Definitions.pdf)': 'TRL 3',
#   'Have you obtained proof of concept for your project?': 'Yes',
#   'Amount of grant funding sought (in SGD)': '187000',
#   'First Name': 'Ogwumah',
#   'Last Name': 'Christopher',
#   'Email address': 'chrisemeka@0xcarbon.co',
#   'Job Role': 'Others',
#   'Organisation': '0xCarbon',
#   'Organisation Industry Type': 'Others',
#   'Organisation Website URL': 'http://-',
#   'Country (Applicant)': 'Nigeria',
#   'Country (Organisation HQ)': 'Nigeria',
#   'Did you receive a nomination invitation with a nomination code?': 'No',
#   'TLC 2024 Applicant Tag': 'TLC 2024 Applicant',
#   'Which theme within The Liveability Challenge is your team working on?': 'Climate Change',
#   'Which SDGs are you tackling with this project? (1):': 'SDG 5: Gender Equality',
#   'Project title': '0xcarbon - Enabling a low carbon economy',
#   'What do you aim to achieve and how would you develop your project if The Liveability Challenge were to provide you with funding or support?': 'Our aim is to provide an accessible and effective solution for businesses in Africa to reduce their carbon footprint and transition to a low-carbon economy. Our ultimate goal is to offset an estimated 10,000,000 tons of CO2e/yr by helping these businesses reduce their carbon footprint. If we were to receive funding or support from The Liveability Challenge, we would use it to further develop and scale our solution.\r\n\r\nSpecifically, we would focus on the following areas:\r\n1. Developing our technology ($74,800): We would invest in the development of our technology platform, including enhancing our big data analytics and machine learning capabilities. This would enable us to provide even more precise and tailored recommendations to our clients, helping them to reduce their carbon footprint even further.\r\n2. Expanding our reach ($28,050): With funding from The Liveability Challenge, we would look to expand our operations beyond our current target market in Nigeria and Kenya to service Southeaster Asia. This would involve building partnerships with businesses and organizations across the continent, as well as exploring opportunities for expansion into other regions.\r\n3. Building our team ($56,000): As we scale up our operations, we would need to build out our team to ensure that we have the capacity to meet demand and continue to innovate. This would involve hiring additional engineers, data scientists, and business development professionals.\r\n4. R&D on Carbon Credit market ($28,150) : We would invest in research and development of carbon credit market both in Africa and Southeaster Asia. The research would help us identify and understand opportunities available in the market and how to best utilize them for carbon credit buyers in Singapore.\r\n\r\nOverall, the support from The Liveability Challenge would be instrumental in helping us to achieve our objectives and accelerate our impact. We believe that our solution has the potential to make a significant contribution towards the global effort to reduce the impact of carbon emissions on the environment, and we are excited about the possibility of collaborating with The Liveability Challenge to make this a reality.',
#   'Current issue to be addressed': 'One of the current issues that 0xcarbon aims to address is the impact of carbon emissions on the environment, specifically in Southeastern Asia. Many businesses in the fast-moving consumer goods (FMCG) sector in Singapore continue to rely on traditional energy sources that emit carbon, contributing to climate change. As a result, there is a pressing need to transition to low-carbon operations to reduce the carbon footprint of these businesses and ultimately contribute to global efforts to combat climate change.',
#   'Proposed solution': '0xcarbon proposes a 3-way SaaS product that leverages big data, machine learning, and blockchain technology to help FMCGs in Africa and Singapore reduce their carbon footprint and transition to a low-carbon economy. The solution provides businesses with suggestions for small incremental changes to their operations, connects them to green energy sources, and processes carbon credits to offset unavoidable emissions.\r\n\r\nThe solution aims to enable businesses to implement sustainable practices and mitigate their environmental impact, ultimately contributing to the global effort to reduce the impact of carbon emissions on the environment. By providing accessible and effective tools for businesses to combat climate change, 0xcarbon aims to play a critical role in catalyzing the transition to a low-carbon economy.',
#   'Impact of proposed solution': 'For carbon credit buyers in Singapore, the solution provides access to high-quality carbon credits generated through the 0xcarbon platform. These carbon credits are backed by rigorous verification processes and support sustainable development initiatives in Africa. By purchasing these carbon credits, buyers can offset their own carbon emissions and contribute to the global effort to combat climate change.\r\n\r\nIn Africa, the solution helps FMCGs to reduce their carbon footprint by providing them with suggestions for small incremental changes to their operations, connecting them to green energy sources, and processing carbon credits to offset unavoidable emissions. This, in turn, helps to reduce the overall carbon emissions in Africa, contributing to the global effort to combat climate change.\r\n\r\nAdditionally, the solution has a positive impact on the local communities in Africa by promoting sustainable practices and providing access to clean energy. This not only helps to reduce carbon emissions but also creates social and economic benefits for local communities, such as improved health outcomes and job opportunities in the renewable energy sector.\r\n\r\nOverall, the proposed solution has a significant positive impact on both Africa and Singapore by promoting sustainable practices, reducing carbon emissions, and supporting sustainable development initiatives.',
#   'Competitive advantage of proposed solution': "Our competitive advantages includes:\r\n1. This unique combination of technologies allows us to offer a comprehensive and innovative solution that goes beyond what traditional carbon offsetting programs provide.\r\n2. Our focus on FMCGs in Africa sets it apart from other carbon offsetting programs, allowing us to target a specific and underserved market.\r\n3. Our solution is flexible and offers small incremental changes so as not to create mishaps of operations during transition.\r\n4. Our company has and imbibes a gender action plan\r\n5. Our solution solves the problem of carbon credit double counting and lack of transparency using blockchain\r\n6. Network effects: As more businesses adopt 0xcarbon's solution, the value proposition of the platform increases. This creates network effects, which can lead to rapid adoption and growth.",
#   'Viable commercial applications of proposed solutions': 'First, it can be used by FMCG companies in Africa to reduce their carbon footprint and comply with environmental regulations, which can give them a competitive advantage and enhance their brand image. Second, the solution can be used by carbon credit buyers in Singapore to offset their own carbon emissions, which can help them meet sustainability targets and enhance their corporate social responsibility profile.\r\n\r\nAdditionally, the solution can be expanded to other sectors beyond FMCG, such as transportation and logistics, which also have significant carbon emissions. By providing actionable insights and recommendations for reducing carbon emissions, 0xcarbon can help these industries become more sustainable and contribute to the global effort to combat climate change.\r\n\r\nFinally, the solution can also be licensed to governments and other organizations that are looking to reduce carbon emissions in their operations. This can provide a recurring revenue stream for 0xcarbon and help it scale up its operations. Overall, the proposed solution has several viable commercial applications that can generate revenue and contribute to a more sustainable future.',
#   'Current competing technologies/competitors': '1. Starsight\r\n2. AS Carbon Credit',
#   'Have commercial partners been engaged?': 'Yes',
#   'Potential commercial partners': 'Commerce & SME Associations\r\n1. NASME (National Association of Small and Meduim Enterprises) LAGOS - Secured\r\n2. Enactus Nigeria (FUTO)\r\n3. Nigerians Chmaber of Commerce\r\n4. Nigerian Ministry of Environment\r\n\r\nCarbon Credit Validation/ Verification bodies (VVBs)\r\n1. VERRA\r\n2. Gold Standard\r\n\r\nAfrican ETS support organizations\r\n1. SE4ALL \r\n\r\nRenewable Energy Associations\r\n1. REEEA-A\r\n2. REAN\r\n3. Global Energy Alliance',
#   'Please elaborate how the above-mentioned commercial partners have been engaged': 'We have approved partnership with NASME Lagos, to onboard 200 members already on our waitlist.',
#   'Has the project applied for funding from other grant institution(s)?': 'No',
#   'Is the project subject to any ethics or regulatory approval requirements?': 'No',
#   'Has the project used, or will be using, any intellectual property or licences from third parties?': 'No',
#   'What will success look like when your project is eventually developed and commercialised?': "Success for 0xcarbon would mean achieving its goal of helping FMCGs in Africa reduce their carbon footprint and transition to a low-carbon economy, while also generating revenue and achieving financial sustainability.\r\n\r\nSpecifically, success would look like:\r\n\r\nSignificant reduction in carbon emissions: 0xcarbon would have helped businesses in Africa reduce their carbon emissions by suggesting sustainable operational changes, connecting them to green energy sources, and processing carbon credits to offset unavoidable emissions. Success would be measured by the amount of CO2e offset through carbon credits and the reduction in emissions achieved by the businesses that adopt 0xcarbon's solutions.\r\nFinancial sustainability: 0xcarbon's revenue streams, including carbon credit sales, subscription fees, and consulting fees, would cover the company's operating expenses and provide a return on investment for investors. Success would be measured by the company's ability to generate revenue and achieve financial sustainability.\r\nMarket penetration: 0xcarbon would have successfully penetrated the African FMCG market and established itself as a leading provider of sustainable solutions. Success would be measured by the number of businesses that adopt 0xcarbon's solutions and the market share captured by the company.\r\nPositive impact on society and the environment: 0xcarbon's solutions would have contributed to the global effort to combat climate change by reducing carbon emissions in Africa. Success would be measured by the positive impact of 0xcarbon's solutions on society and the environment.\r\nRecognition and awards: 0xcarbon's success would be recognized by industry experts, investors, and the public through various awards and accolades. Success would be measured by the number and prestige of awards received by the company.",
#   'What is the biggest possible impact imaginable for your technology/innovation (beyond the scope of the project)?': "The biggest possible impact imaginable for 0xcarbon's technology/innovation would be the widespread adoption of low-carbon practices across industries and regions globally. If businesses across the world were to adopt similar solutions to 0xcarbon's, the resulting reduction in carbon emissions would have a significant positive impact on the environment and climate change. In addition to mitigating the negative effects of climate change, the widespread adoption of low-carbon practices could lead to the creation of new jobs and economic opportunities in the renewable energy sector. It could also improve air quality, decrease reliance on fossil fuels, and promote more sustainable resource management. Ultimately, the biggest impact of 0xcarbon's technology would be to contribute towards a more sustainable and livable planet for future generations.",
#   'Any existing work/phase(s) already completed?': 'Yes',
#   'Briefly describe the work/phase(s) already completed': 'So far we have bootstrapped $7,450 from friends and family, onboarded 3 businesses, secured over 200 potential users through our 3 major partnerships, and gotten 20,000 waitlist sign-ups on our website from October to February. The next steps for 0xcarbon involve building out our MVP, growing our team, expanding our client base, securing more strategic partners and advisors, and marketing efforts.',
#   "Proposed project's scope of work": 'Developing and implementing a SaaS platform that leverages big data, machine learning, and blockchain technology to help FMCGs in Africa reduce their carbon footprint and transition to a low-carbon economy. The platform would provide businesses with suggestions for small incremental changes to their operations, connect them to green energy sources, and process carbon credits to offset unavoidable emissions.\r\n\r\nThe project would involve conducting market research and identifying potential clients in the African FMCG sector, as well as establishing partnerships with green energy providers and carbon credit buyers in Singapore.\r\nA marketing and sales strategy would also need to be developed to effectively reach potential clients and generate revenue for the company.\r\n\r\nOverall, the scope of work for this project would involve a combination of software development, market research, partnership building, and marketing/sales efforts to successfully launch and scale the 0xcarbon platform.',
#   'Please include any other remark or information useful in supporting your application': 'Our shared goal of sustainability and inclusion aligns with the Liveability goal of promoting a more equitable and sustainable future for all.',
#   'How did you hear about the Liveability Challenge? (1):': 'Word of Mouth',
#   'You will be allowed to edit your application once it is submitted via the link sent to your email. If you do not receive it, please contact tlc@eco-business.com and we will be happy to assist you. (1):': "I confirm that all details in my submission is correct, and I'm submitting this as the final entry for review by the TLC committee."}}

# %%
# Find all unique challange types
unique_challenges = set()
for entry in data.values():
    unique_challenges.add(entry["Challenge"])
print(unique_challenges)
# Out:
# {'Climate Impact Innovations Challenge 2023', 'The Liveability Challenge 2022', 'Net Zero Challenge 2023', 'The Liveability Challenge 2023', 'The Liveability Challenge Form 2025', 'Climate Impact Innovations Challenge 2024', 'Liveability Challenge 2024', 'Net Zero Challenge 2024'}

# %%
# User status count and occurances
user_status_count = {}
for entry in data.values():
    if entry["user_status"] in user_status_count:
        user_status_count[entry["user_status"]] += 1
    else:
        user_status_count[entry["user_status"]] = 1
print(user_status_count)
# Out:
# {'Pending': 685, 'Yes': 85, 'KIV': 94, 'No': 1225, 'Maybe': 19, 'No ': 3, 'nan': 2, '': 246, 'Reject': 180, 'Recommended': 26}

# %%
data["30"].keys()
# Out:
# dict_keys(['organization', 'theme_id', 'kyc_completed', 'display_id', 'challenge_id', 'country', 'sub_category_id', 'categorizer_completed', 'category_id', 'evaluator_completed', 'attachment_extractor_completed', 'assigned_reviewer', 'extractor_completed', 'user_status', 'user_comments', 'created_at', 'id', 'LLM_summary', 'updated_at', 'title', 'LLM_status', 'jotform_id', 'pre_aug_sixth', 'Challenge', 'Theme', 'Category', 'Subcategory', 'form_fields'])

# %%
# Input features on which we will decide whether to give a grant or not
input_keys = [
    "Challenge",
    "What do you aim to achieve and how would you develop your project if The Liveability Challenge were to provide you with funding or support?",
]

# Whether the grant was accepted or not.
output_key = "user_status"

# %%
"""LLM_summary
Theme
Category
Subcategory
Project objectives
Current issue to be addressed
Proposed solution
Impact of proposed solution
Competitive advantage of proposed solution
Viable commercial applications of proposed solutions
Current competing technologies/competitors
Project stage (TRL)
Amount of grant funding sought (in SGD)
Proof of concept status
Commercial partners engaged
Scope of work
Biggest possible impact
Success metrics
Remarks/supporting information"""
# Out:
# 'LLM_summary\nTheme\nCategory\nSubcategory\nProject objectives\nCurrent issue to be addressed\nProposed solution\nImpact of proposed solution\nCompetitive advantage of proposed solution\nViable commercial applications of proposed solutions\nCurrent competing technologies/competitors\nProject stage (TRL)\nAmount of grant funding sought (in SGD)\nProof of concept status\nCommercial partners engaged\nScope of work\nBiggest possible impact\nSuccess metrics\nRemarks/supporting information'

# %%
yes_label_list = ["Yes", "Recommended"]
no_label_list = ["No", "No ", "Reject"]


def get_dict_entry(entry: dict, key: str) -> str:
    if key in entry:
        return entry[key]
    elif key in entry["form_fields"]:
        return entry["form_fields"][key]
    else:
        return "None"


def convert_entry_to_prompt(grant_entry: dict) -> str:
    # Generating the prompt with the data
    prompt = f"""
    Given the following details of a grant application, determine the likelihood of acceptance. 
    Assess how well the project aligns with the challenge theme, its viability, its potential impact, and any competitive advantage. 
    Consider the stage of development, the proof of concept status, and existing partnerships. 
    Classify the likelihood of acceptance as 'High', 'Medium', or 'Low', and briefly explain your rationale.

    Grant Application Summary:
    - **Project Theme:** {get_dict_entry(grant_entry, 'Theme')}
    - **Category:** {get_dict_entry(grant_entry, 'Category')}
    - **Subcategory:** {get_dict_entry(grant_entry, 'Subcategory')}
    - **Project Title:** {get_dict_entry(grant_entry, 'title')}
    - **Grant Amount Sought:** {get_dict_entry(grant_entry, 'Amount of grant funding sought (in SGD)')}
    - **Objectives:** {get_dict_entry(grant_entry, 'Project objectives')}
    - **Have you obtained proof of concept for your project?** {get_dict_entry(grant_entry, 'Have you obtained proof of concept for your project?')}

    Solution Summary: {get_dict_entry(grant_entry, 'LLM_summary')}

    Proposed solution: {get_dict_entry(grant_entry, 'Proposed solution')}

    Proposed project's scope of work: {get_dict_entry(grant_entry, "Proposed project's scope of work")}

    Classify the likelihood of acceptance and briefly explain why this project meets or does not meet the challenge's acceptance criteria.
    """

    return prompt


def make_training_example(entry: dict) -> tuple[str, str]:
    prompt = convert_entry_to_prompt(entry)
    if entry[output_key] in yes_label_list:
        return prompt, "Yes"
    elif entry[output_key] in no_label_list:
        return prompt, "No"
    else:
        return None


# Just a test
for i, d in enumerate(data.values()):
    te = make_training_example(d)
    if te is not None:
        print(f"Entry {i}")
        print(te[0])
        print(te[1])

    if i > 10:
        break
# Out:
# Entry 1
#
#     Given the following details of a grant application, determine the likelihood of acceptance.
#     Assess how well the project aligns with the challenge theme, its viability, its potential impact, and any competitive advantage.
#     Consider the stage of development, the proof of concept status, and existing partnerships.
#     Classify the likelihood of acceptance as 'High', 'Medium', or 'Low', and briefly explain your rationale.
#
#     Grant Application Summary:
#     - **Project Theme:** Climate Change
#     - **Category:** Carbon Management
#     - **Subcategory:** Carbon Emissions Reduction through SaaS
#     - **Project Title:** 0xcarbon - Enabling a low carbon economy
#     - **Grant Amount Sought:** 187000
#     - **Objectives:** Our primary objective at 0xcarbon is to help FMCGs in Africa reduce their carbon footprint and transition to a low-carbon economy. The company's goal is to leverage big data, machine learning, and blockchain technology to provide actionable insights and solutions to these businesses, enabling them to make incremental changes to their operations that reduce their carbon emissions. By doing so, 0xcarbon aims to offset an estimated 10,000,000 tons of CO2e/yr and contribute to the global effort to combat climate change. Additionally, the company aims to create a sustainable business model that generates revenue while driving positive environmental impact, demonstrating the viability of market-based solutions for addressing sustainability challenges.
#     - **Have you obtained proof of concept for your project?** Yes
#
#     Solution Summary: 0xcarbon is a SaaS product that helps FMCG businesses in Southeast Asia reduce their carbon footprint. It uses big data, machine learning, and blockchain technology to provide businesses with suggestions for small incremental changes to their operations, connect them to green energy sources, and process carbon credits to offset unavoidable emissions. By providing accessible and effective tools for businesses to combat climate change, 0xcarbon aims to play a critical role in catalyzing the transition to a low-carbon economy.
#
#     Proposed solution: 0xcarbon proposes a 3-way SaaS product that leverages big data, machine learning, and blockchain technology to help FMCGs in Africa and Singapore reduce their carbon footprint and transition to a low-carbon economy. The solution provides businesses with suggestions for small incremental changes to their operations, connects them to green energy sources, and processes carbon credits to offset unavoidable emissions.
#
# The solution aims to enable businesses to implement sustainable practices and mitigate their environmental impact, ultimately contributing to the global effort to reduce the impact of carbon emissions on the environment. By providing accessible and effective tools for businesses to combat climate change, 0xcarbon aims to play a critical role in catalyzing the transition to a low-carbon economy.
#
#     Proposed project's scope of work: Developing and implementing a SaaS platform that leverages big data, machine learning, and blockchain technology to help FMCGs in Africa reduce their carbon footprint and transition to a low-carbon economy. The platform would provide businesses with suggestions for small incremental changes to their operations, connect them to green energy sources, and process carbon credits to offset unavoidable emissions.
#
# The project would involve conducting market research and identifying potential clients in the African FMCG sector, as well as establishing partnerships with green energy providers and carbon credit buyers in Singapore.
# A marketing and sales strategy would also need to be developed to effectively reach potential clients and generate revenue for the company.
#
# Overall, the scope of work for this project would involve a combination of software development, market research, partnership building, and marketing/sales efforts to successfully launch and scale the 0xcarbon platform.
#
#     Classify the likelihood of acceptance and briefly explain why this project meets or does not meet the challenge's acceptance criteria.
#
# Yes
# Entry 2
#
#     Given the following details of a grant application, determine the likelihood of acceptance.
#     Assess how well the project aligns with the challenge theme, its viability, its potential impact, and any competitive advantage.
#     Consider the stage of development, the proof of concept status, and existing partnerships.
#     Classify the likelihood of acceptance as 'High', 'Medium', or 'Low', and briefly explain your rationale.
#
#     Grant Application Summary:
#     - **Project Theme:** Climate Change
#     - **Category:** Circular Economy
#     - **Subcategory:** Circular Product Ecosystem
#     - **Project Title:** CirQu Digital ID
#     - **Grant Amount Sought:** 100000
#     - **Objectives:** CirQu extends products life by enabling circular ecosystem (upcycling, recycling, thrifting and more) before it reaches landfills. It interlinks brands, consumers, and circularity enablers, providing real-time sustainability metrics for each product across its lifecycle. It enhances transparency and accountability, enabling informed consumer choices and assisting brands in their ‘extended producers responsibility’. And It provides an opportunity to grow the circularity enablers network and channel products into circularity.
#     - **Have you obtained proof of concept for your project?** Yes
#
#     Solution Summary: CirQu Digital ID aims to address environmental pollution and excessive carbon emissions by creating a cohesive digital infrastructure that connects circularity enablers, brands, and consumers. This platform extends product life by facilitating reusability, reducing waste, and enabling responsible disposal, ultimately creating a more sustainable and eco-friendly future. By providing real-time sustainability metrics for each product across its lifecycle, CirQu Digital ID enhances transparency and accountability, enabling informed consumer choices and assisting brands in their extended producers responsibility.
#
#     Proposed solution: CirQu Digital ID addresses this critical need by creating a cohesive digital infrastructure that links circularity enablers, brands, and consumers. A robust connection would enable extension of product and material life. This streamlined connection has the potential to enhance a product's shelf life by facilitating reusability, reducing waste, and enabling responsible disposal, ultimately creating a more sustainable and eco-friendly future.
#
# Sustainability is not just an option but a responsibility and bridging the gap between intention and action is imperative. The motivation for designing and building CirQu stems from a keen interest to approach circularity scientifically and build a measurable and impactful platform.
#
# Background: At Astu Eco, we started with manufacturing, trading and retail of sustainable alternatives and graduated to a Zero Waste experiential hub with Upcycling services. We felt the need to understand our own impact and what started as a inhouse project is today CirQu, a Saas Platform, that enables circular economy in fashion.
#
# CirQu Digital ID Platform:
# CirQu extends products life by enabling circular ecosystem (upcycling, recycling, thrifting and more) before it reaches landfills. It interlinks brands, consumers, and circularity enablers, providing real-time sustainability metrics for each product across its lifecycle. It enhances transparency and accountability, enabling informed consumer choices and assisting brands in their ‘extended producers responsibility’. And It provides an opportunity to grow the circularity enablers network and channel products into circularity.
#
# Imagine a seamlessly connected ecosystem where Brands are empowered with comprehensive data, enabling them to not only meet sustainability goals through EPR channel but also enhance brand value and financial viability.
#
# Picture consumers who can instantly verify a product's sustainability claims, effortlessly measure their individual environmental contributions, and make informed choices—all at the swipe of a finger.
#
# CirQu Digital ID turns sustainability into a tangible, measurable reality. By providing real-time, quantifiable data on a product's environmental impact, carbon footprint, and sustainability credentials, it transforms conscientious consumerism into a powerful force for change. It amplifies the circular economy by extending the life of products and materials, minimizing waste, and fostering a sustainable future.
# Through CirQu Digital ID, we envision a world where every product's journey is transparent, every choice is impactful, and sustainability is not just a buzzword but a way of life.
#
#
#     Proposed project's scope of work: None
#
#     Classify the likelihood of acceptance and briefly explain why this project meets or does not meet the challenge's acceptance criteria.
#
# Yes
# Entry 3
#
#     Given the following details of a grant application, determine the likelihood of acceptance.
#     Assess how well the project aligns with the challenge theme, its viability, its potential impact, and any competitive advantage.
#     Consider the stage of development, the proof of concept status, and existing partnerships.
#     Classify the likelihood of acceptance as 'High', 'Medium', or 'Low', and briefly explain your rationale.
#
#     Grant Application Summary:
#     - **Project Theme:** Climate Change
#     - **Category:** Environmental Sustainability
#     - **Subcategory:** Sustainable Menstrual Hygiene
#     - **Project Title:** Saathi: 100% biodegradable and compostable sanitary pads
#     - **Grant Amount Sought:** 1000000
#     - **Objectives:** Potential Impact at scale:
#
# Awareness among 27500 womens about Sustainable Menstrual Hygiene, now having safe and sustainable periods.
#
# CO2 emission saved
# (in Kg) - 89100 in 12 months.
#
# Plastic Saved
# (in Kgs) - 46200 in 12 months.
#
# Total Pad Distributed/Sold - 3.3 Million pads in 12 months.
#
# 10000 women having Increased Social Mobility on days of Menstruation and Improved menstrual hygiene practices resulting in positive health outcomes.
#
# Save $6.87M SGD -  Medical Expense
#
# Save $8.25M SGD - Income Loss to Women
#
# Generate Plastic Credit  (1000 kg of plastic waste is equivalent to 1 Plastic Credit) - 46.2 credits values at $12320.00 SGD
#
# Generate Carbon Credit (1000 kg of plastic waste is equivalent to 1 Carbon Credit) - 89.10 credits values at $4752.00 SGD
#
# Launch pilot in SE Asia to determine the local impacts that we would have with a similar program so we can scale beyond India.
#     - **Have you obtained proof of concept for your project?** Yes
#
#     Solution Summary: Saathi tackles the issue of unhygienic and environmentally harmful sanitary pads by providing biodegradable and compostable pads made from banana and bamboo fibers. These pads are designed to minimize skin irritation and environmental impact, degrading within 6 months of disposal, 1200 times faster than conventional pads. Saathi aims to expand its reach in India and Southeast Asia to provide a sustainable and healthy solution for women.
#
#     Proposed solution: Saathi has developed 100% biodegradable pads and compostable sanitary pads from banana and bamboo fibers. Our all-natural pads do not contain bleach or chemicals to minimize skin irritation and release of toxins into the environment upon disposal. Not only are they more comfortable and safer for the user, but Saathi pads also degrade within 6 months of disposal, 1200 times faster than conventional pads, and eliminate the need for incineration, reducing CO2 production. With our solution, we want to not only scale the reach in India but also pilot reach in SE Asia to ensure that we can have local impacts as we grow and expand internationally.
#
#     Proposed project's scope of work: Potential Impact at scale:
#
# Awareness among 27500 womens about Sustainable Menstrual Hygiene, now having safe and sustainable periods.
#
# CO2 emission saved
# (in Kg) - 89100 in 12 months.
#
# Plastic Saved
# (in Kgs) - 46200 in 12 months.
#
# Total Pad Distributed/Sold - 3.3 Million pads in 12 months.
#
# 10000 women having Increased Social Mobility on days of Menstruation and Improved menstrual hygiene practices resulting in positive health outcomes.
#
# Save $6.87M SGD -  Medical Expense
#
# Save $8.25M SGD - Income Loss to Women
#
# Generate Plastic Credit  (1000 kg of plastic waste is equivalent to 1 Plastic Credit) - 46.2 credits values at $12320.00 SGD
#
# Generate Carbon Credit (1000 kg of plastic waste is equivalent to 1 Carbon Credit) - 89.10 credits values at $4752.00 SGD
#
#     Classify the likelihood of acceptance and briefly explain why this project meets or does not meet the challenge's acceptance criteria.
#
# Yes
# Entry 8
#
#     Given the following details of a grant application, determine the likelihood of acceptance.
#     Assess how well the project aligns with the challenge theme, its viability, its potential impact, and any competitive advantage.
#     Consider the stage of development, the proof of concept status, and existing partnerships.
#     Classify the likelihood of acceptance as 'High', 'Medium', or 'Low', and briefly explain your rationale.
#
#     Grant Application Summary:
#     - **Project Theme:** Climate Change
#     - **Category:** Battery Management
#     - **Subcategory:** Battery Life Extension
#     - **Project Title:** BAVERTIS
#     - **Grant Amount Sought:** 1100000
#     - **Objectives:** BAVERTIS has developed a breakthrough solution combining latest semiconductor
# technology and AI-based software to extend the life of electric vehicle battery
# packs by 80%, while enabling them to be reused in new applications through a
# simple software update, unlocking the future of circular batteries in mobility!
#     - **Have you obtained proof of concept for your project?** Yes
#
#     Solution Summary: This application aims to address the short lifecycles of EV batteries and the lack of an easy way to repurpose them. The proposed solution can be integrated into EV battery packs and would allow manufacturers to easily repurpose used batteries for stationary storage applications.
#
#     Proposed solution: The solution can be implemented to almost all EV-battery packs bigger than those for an E-Scooter. For this reason every manufacturer active in the field of battery packs for EVs could be a potential partner and implement our solution.
#
#     Proposed project's scope of work: The next steps are focused on enhancing the design for (large scale) industry production, conformity of functional safety aspects, cost & design optimization.
#
#     Classify the likelihood of acceptance and briefly explain why this project meets or does not meet the challenge's acceptance criteria.
#
# Yes
